# %%
import time

from abc import ABCMeta, abstractmethod
import numpy as np
import tensorflow as tf
import scipy
import scipy.stats as stats
from tensorflow.examples.tutorials.mnist import input_data
from im2col_cython import col2im_cython, im2col_cython
import os
import math
import pickle
import matplotlib.pyplot as plt

import skimage as ski
import skimage.io


DATA_DIR = '/home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/'
SAVE_DIR = "/home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/out/"

# %% [markdown]
# # layers.py

# %%
zero_init = np.zeros

def variance_scaling_initializer(shape, fan_in, factor=2.0, seed=None):
  sigma = np.sqrt(factor / fan_in)
  return stats.truncnorm(-2, 2, loc=0, scale=sigma).rvs(shape)


# -- ABSTRACT CLASS DEFINITION --
class Layer(metaclass = ABCMeta):
  "Interface for layers"
  # See documentation of abstract base classes (ABC): https://docs.python.org/3/library/abc.html

  @abstractmethod
  def forward(self, inputs):
    """
    Args:
      inputs: ndarray tensor.
    Returns:
      ndarray tensor, result of the forward pass.
    """
    pass

  @abstractmethod
  def backward_inputs(self, grads):
    """
    Args:
      grads: gradient of the loss with respect to the output of the layer.
    Returns:
      Gradient of the loss with respect to the input of the layer.
    """
    pass

  def backward_params(self, grads):
    """
    Args:
      grads: gradient of the loss with respect to the output of the layer.
    Returns:
      Gradient of the loss with respect to all the parameters of the layer as a list
      [[w0, g0], ..., [wk, gk], self.name] where w are parameter weights and g their gradient.
      Note that wk and gk must have the same shape.
    """
    pass


# -- CONVOLUTION LAYER --
class Convolution(Layer):
  "N-dimensional convolution layer"

  def __init__(self, input_layer, num_filters, kernel_size, name, padding='SAME',
               weights_initializer_fn=variance_scaling_initializer,
               bias_initializer_fn=zero_init):
    self.input_shape = input_layer.shape
    N, C, H, W = input_layer.shape
    self.C = C
    self.N = N
    self.num_filters = num_filters
    self.kernel_size = kernel_size

    assert kernel_size % 2 == 1

    self.padding = padding
    if padding == 'SAME':
      # with zero padding
      self.shape = (N, num_filters, H, W)
      self.pad = (kernel_size - 1) // 2
    else:
      # without padding
      self.shape = (N, num_filters, H - kernel_size + 1, W - kernel_size + 1)
      self.pad = 0

    fan_in = C * kernel_size**2
    self.weights = weights_initializer_fn([num_filters, kernel_size**2 * C], fan_in)
    self.bias = bias_initializer_fn([num_filters])
    # this implementation doesn't support strided convolutions
    self.stride = 1
    self.name = name
    self.has_params = True

  def forward(self, x):
    k = self.kernel_size
    self.x_cols = im2col_cython(x, k, k, self.pad, self.stride)
    res = self.weights.dot(self.x_cols) + self.bias.reshape(-1, 1)
    N, C, H, W = x.shape
    out = res.reshape(self.num_filters, H, W, N)
    return out.transpose(3, 0, 1, 2)

  def backward_inputs(self, grad_out):
    # nice trick from CS231n, backward pass can be done with just matrix mul and col2im
    grad_out = grad_out.transpose(1, 2, 3, 0).reshape(self.num_filters, -1)
    grad_x_cols = self.weights.T.dot(grad_out)
    N, C, H, W = self.input_shape
    k = self.kernel_size
    grad_x = col2im_cython(grad_x_cols, N, C, H, W, k, k, self.pad, self.stride)
    return grad_x

  def backward_params(self, grad_out):
    grad_bias = np.sum(grad_out, axis=(0, 2, 3))
    grad_out = grad_out.transpose(1, 2, 3, 0).reshape(self.num_filters, -1)
    grad_weights = grad_out.dot(self.x_cols.T).reshape(self.weights.shape)
    return [[self.weights, grad_weights], [self.bias, grad_bias], self.name]


class MaxPooling(Layer):
  def __init__(self, input_layer, name, pool_size=2, stride=2):
    self.name = name
    self.input_shape = input_layer.shape
    N, C, H, W = self.input_shape
    self.stride = stride
    self.shape = (N, C, H // stride, W // stride)
    self.pool_size = pool_size
    assert pool_size == stride, 'Invalid pooling params'
    assert H % pool_size == 0
    assert W % pool_size == 0
    self.has_params = False

  def forward(self, x):
    N, C, H, W = x.shape
    self.input_shape = x.shape
    # with this clever reshaping we can implement pooling where pool_size == stride
    self.x = x.reshape(N, C, H // self.pool_size, self.pool_size,
                       W // self.pool_size, self.pool_size)
    self.out = self.x.max(axis=3).max(axis=4)
    # if you are returning class member be sure to return a copy
    return self.out.copy()

  def backward_inputs(self, grad_out):
    grad_x = np.zeros_like(self.x)
    out_newaxis = self.out[:, :, :, np.newaxis, :, np.newaxis]
    mask = (self.x == out_newaxis)
    dout_newaxis = grad_out[:, :, :, np.newaxis, :, np.newaxis]
    dout_broadcast, _ = np.broadcast_arrays(dout_newaxis, grad_x)
    # this is almost the same as the real backward pass
    grad_x[mask] = dout_broadcast[mask]
    # in the very rare case that more then one input have the same max value
    # we can aprox the real gradient routing by evenly distributing across multiple inputs
    # but in almost all cases this sum will be 1
    grad_x /= np.sum(mask, axis=(3, 5), keepdims=True)
    grad_x = grad_x.reshape(self.input_shape)
    return grad_x


class Flatten(Layer):
  def __init__(self, input_layer, name):
    self.input_shape = input_layer.shape
    self.N = self.input_shape[0]
    self.num_outputs = 1
    for i in range(1, len(self.input_shape)):
      self.num_outputs *= self.input_shape[i]
    self.shape = (self.N, self.num_outputs)
    self.has_params = False
    self.name = name

  def forward(self, inputs):
    self.input_shape = inputs.shape
    inputs_flat = inputs.reshape(self.input_shape[0], -1)
    self.shape = inputs_flat.shape
    return inputs_flat

  def backward_inputs(self, grads):
    return grads.reshape(self.input_shape)

class FC(Layer):
  def __init__(self, input_layer, num_outputs, name,
               weights_initializer_fn=variance_scaling_initializer,
               bias_initializer_fn=zero_init):
    """
    Args:
      input_layer: layer below
      num_outputs: number of neurons in this layer
      weights_initializer_fn: initializer function for weights,
      bias_initializer_fn: initializer function for biases
    """
    

    self.input_shape = input_layer.shape #fc3 (50, 1568) #logits #fc3 (50, 512)
    self.N = self.input_shape[0] #50
    self.shape = (self.N, num_outputs) #fc3 (50, 512) #logits #fc3 (50, 10)
    self.num_outputs = num_outputs #fc3 512 #logits 10

    self.num_inputs = 1 #fc3 1568 #logits 512
    for i in range(1, len(self.input_shape)):
      self.num_inputs *= self.input_shape[i] 

    #fc3 (512,1568) #logits (10,512)
    self.weights = weights_initializer_fn([num_outputs, self.num_inputs], fan_in=self.num_inputs) 
    self.bias = bias_initializer_fn([num_outputs]) #fc3 (512,) #logits (10,)
    self.name = name
    self.has_params = True
    

  def forward(self, inputs):
    """ 
    Args:
      inputs: ndarray of shape (N, num_inputs) #fc3 (50,1568) #logits (50,512)
    Returns:
      An ndarray of shape (N, num_outputs) #fc3 (50,512) #logits (50,10)
    """
    self.inputs = inputs
    N, num_inputs = inputs.shape
    return np.dot(inputs, self.weights.T) + self.bias    

  def backward_inputs(self, grads):
    """ 
    Args:
      grads: ndarray of shape (N, num_outputs) #fc3 (50,512) #logits (50,10)
    Returns:
      An ndarray of shape (N, num_inputs) #fc3 (50,1568) #logits (50,512)
    """
    return np.dot(grads, self.weights)


  def backward_params(self, grads):
        
    """
    Args:
      grads: ndarray of shape (N, num_outputs) #fc3 (50,512) #logits (50,10)
    Returns:
      List of params and gradient pairs.
    """
    grad_weights = np.dot(grads.T, self.inputs)
    grad_bias = np.sum(grads, axis = 0, keepdims=True).flatten()    
    return [[self.weights, grad_weights], [self.bias, grad_bias], self.name]



class ReLU(Layer):
  def __init__(self, input_layer, name):
    self.shape = input_layer.shape
    self.name = name
    self.has_params = False

  def forward(self, inputs):
    """
    Args:
      inputs: ndarray of shape (N, C, H, W).
    Returns:
      ndarray of shape (N, C, H, W).
    """
    self.inputs = inputs
    self.forw = np.maximum(0,inputs)
    return np.maximum(0,inputs)

  def backward_inputs(self, grads):
    """
    Args:
      grads: ndarray of shape (N, C, H, W).
    Returns:
      ndarray of shape (N, C, H, W).
    """
    gated = np.copy(grads)
    grads[self.forw <= 0] = 0.0
    return grads
    
class SoftmaxCrossEntropyWithLogits():
  def __init__(self):
    self.has_params = False

  def forward(self, x, y):
    """
    Args:
      x: ndarray of shape (N, num_classes).
      y: ndarray of shape (N, num_classes).
    Returns:
      Scalar, average loss over N examples.
      It is better to compute average loss here instead of just sum
      because then learning rate and weight decay won't depend on batch size.
    """
    N = x.shape[0]
    sx = np.exp(x) / np.sum(np.exp(x), axis=1, keepdims=True)
    return np.sum(-(np.log(sx) * y)) / N

  def backward_inputs(self, x, y):
    """
    Args:
      x: ndarray of shape (N, num_classes).
      y: ndarray of shape (N, num_classes).
    Returns:
      Gradient with respect to the x, ndarray of shape (N, num_classes).
    """
    N = x.shape[0]
    sx = np.exp(x) / np.sum(np.exp(x), axis=1, keepdims=True) 
    return (sx - y) / N

class L2Regularizer():
  def __init__(self, weights, weight_decay, name):
    """
    Args:
      weights: parameters which will be regularizerized
      weight_decay: lambda, regularization strength
      name: layer name
    """
    # this is still a reference to original tensor so don't change self.weights
    self.weights = weights
    self.weight_decay = weight_decay
    self.name = name

  def forward(self):
    """
     Returns:
      Scalar, loss due to the L2 regularization.
    """
    s = 0.5 * self.weight_decay * np.sum(self.weights * self.weights)
    
    return s

  def backward_params(self):
    """
    Returns:
      Gradient of the L2 loss with respect to the regularized weights.
    """
    grad_weights = self.weight_decay*self.weights
    return [[self.weights, grad_weights], self.name]


class RegularizedLoss():
  def __init__(self, data_loss, regularizer_losses):
    self.data_loss = data_loss
    self.regularizer_losses = regularizer_losses
    self.has_params = True
    self.name = 'RegularizedLoss'

  def forward(self, x, y):
    loss_val = self.data_loss.forward(x, y)
    for loss in self.regularizer_losses:
      loss_val += loss.forward()
    return loss_val

  def backward_inputs(self, x, y):
    return self.data_loss.backward_inputs(x, y)

  def backward_params(self):
    grads = []
    for loss in self.regularizer_losses:
      grads += [loss.backward_params()]
    return grads

# %% [markdown]
# # nn.py

# %%
def forward_pass(net, inputs):
  output = inputs
  for layer in net:
    output = layer.forward(output)
  return output


def backward_pass(net, loss, x, y):
  grads = []
  grad_out = loss.backward_inputs(x, y)
  if loss.has_params:
    grads += loss.backward_params()
  for layer in reversed(net):
    grad_inputs = layer.backward_inputs(grad_out)
    if layer.has_params:
      grads += [layer.backward_params(grad_out)]
    grad_out = grad_inputs
  return grads

def sgd_update_params(grads, config):
  lr = config['lr']
  for layer_grads in grads:
    for i in range(len(layer_grads) - 1):
      params = layer_grads[i][0]
      grads = layer_grads[i][1]
      #print(layer_grads[-1], " -> ", grads.sum())
      params -= lr * grads
      

def draw_conv_filters(epoch, step, layer, save_dir):
  C = layer.C
  w = layer.weights.copy()
  num_filters = w.shape[0]
  k = int(np.sqrt(w.shape[1] / C))
  w = w.reshape(num_filters, C, k, k)
  w -= w.min()
  w /= w.max()
  border = 1
  cols = 8
  rows = math.ceil(num_filters / cols)
  width = cols * k + (cols-1) * border
  height = rows * k + (rows-1) * border
  #for i in range(C):
  for i in range(1):
    img = np.zeros([height, width])
    for j in range(num_filters):
      r = int(j / cols) * (k + border)
      c = int(j % cols) * (k + border)
      img[r:r+k,c:c+k] = w[j,i]
    filename = '%s_epoch_%02d_step_%06d_input_%03d.png' % (layer.name, epoch, step, i)
    ski.io.imsave(os.path.join(save_dir, filename), img)


def train(train_x, train_y, valid_x, valid_y, net, loss, config):
  lr_policy = config['lr_policy']
  batch_size = config['batch_size']
  max_epochs = config['max_epochs']
  save_dir = config['save_dir']
  num_examples = train_x.shape[0]
  assert num_examples % batch_size == 0
  num_batches = num_examples // batch_size
  for epoch in range(1, max_epochs+1):
    epoch_batch_steps = []
    epoch_batch_losses = []
    if epoch in lr_policy:
      solver_config = lr_policy[epoch]
    cnt_correct = 0
    #for i in range(num_batches):
    # shuffle the data at the beggining of each epoch
    permutation_idx = np.random.permutation(num_examples)
    train_x = train_x[permutation_idx]
    train_y = train_y[permutation_idx]
    #for i in range(100):
    for i in range(num_batches):
      # store mini-batch to ndarray
      batch_x = train_x[i*batch_size:(i+1)*batch_size, :]
      batch_y = train_y[i*batch_size:(i+1)*batch_size, :]
      logits = forward_pass(net, batch_x)
      loss_val = loss.forward(logits, batch_y)
      # compute classification accuracy
      yp = np.argmax(logits, 1)
      yt = np.argmax(batch_y, 1)
      cnt_correct += (yp == yt).sum()
      grads = backward_pass(net, loss, logits, batch_y)
      sgd_update_params(grads, solver_config)

      if i % 50 == 0:
        epoch_batch_steps.append(i*batch_size)
        epoch_batch_losses.append(loss_val)
        print("epoch %d, step %d/%d, batch loss = %.2f" % (epoch, i*batch_size, num_examples, loss_val))
      if i % 100 == 0:
        draw_conv_filters(epoch, i*batch_size, net[0], save_dir)
        #draw_conv_filters(epoch, i*batch_size, net[3])
      if i > 0 and i % 50 == 0:
        pass
        #print("Train accuracy = %.2f" % (cnt_correct / ((i+1)*batch_size) * 100))
    print("Epoch %d:" % epoch)
    print("Train accuracy = %.2f" % (cnt_correct / num_examples * 100))
    evaluate("Validation", valid_x, valid_y, net, loss, config)
    plt.plot(epoch_batch_steps,epoch_batch_losses)
    plt.show()
  return net


def evaluate(name, x, y, net, loss, config):
  print("\nRunning evaluation: ", name)
  batch_size = config['batch_size']
  num_examples = x.shape[0]
  assert num_examples % batch_size == 0
  num_batches = num_examples // batch_size
  cnt_correct = 0
  loss_avg = 0
  for i in range(num_batches):
    batch_x = x[i*batch_size:(i+1)*batch_size, :]
    batch_y = y[i*batch_size:(i+1)*batch_size, :]
    logits = forward_pass(net, batch_x)
    yp = np.argmax(logits, 1)
    yt = np.argmax(batch_y, 1)
    cnt_correct += (yp == yt).sum()
    loss_val = loss.forward(logits, batch_y)
    loss_avg += loss_val
    #print("step %d / %d, loss = %.2f" % (i*batch_size, num_examples, loss_val / batch_size))
  valid_acc = cnt_correct / num_examples * 100
  loss_avg /= num_batches
  print(name + " accuracy = %.2f" % valid_acc)
  print(name + " avg loss = %.2f\n" % loss_avg)

# %% [markdown]
# # train.py

# %%
config = {}
config['max_epochs'] = 5
config['batch_size'] = 50
config['save_dir'] = SAVE_DIR
config['lr_policy'] = {1:{'lr':1e-1}, 3:{'lr':1e-2}, 5:{'lr':1e-3}, 7:{'lr':1e-4}}

#np.random.seed(100) 
np.random.seed(int(time.time() * 1e6) % 2**31)
dataset = input_data.read_data_sets(DATA_DIR, one_hot=True)
train_x = dataset.train.images
train_x = train_x.reshape([-1, 1, 28, 28])
train_y = dataset.train.labels
valid_x = dataset.validation.images
valid_x = valid_x.reshape([-1, 1, 28, 28])
valid_y = dataset.validation.labels
test_x = dataset.test.images
test_x = test_x.reshape([-1, 1, 28, 28])
test_y = dataset.test.labels
train_mean = train_x.mean()
train_x -= train_mean
valid_x -= train_mean
test_x -= train_mean

print('train_x.shape = %s'%str(train_x.shape))
print('train_y.shape = %s'%str(train_y.shape))
print('valid_x.shape = %s'%str(valid_x.shape))
print('valid_y.shape = %s'%str(valid_y.shape))
print('test_x.shape = %s'%str(test_x.shape))
print('test_y.shape = %s'%str(test_y.shape))
# Out:
# Extracting /home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/train-images-idx3-ubyte.gz
# Extracting /home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/train-labels-idx1-ubyte.gz
# Extracting /home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/t10k-images-idx3-ubyte.gz
# Extracting /home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/t10k-labels-idx1-ubyte.gz
# train_x.shape = (55000, 1, 28, 28)
# train_y.shape = (55000, 10)
# valid_x.shape = (5000, 1, 28, 28)
# valid_y.shape = (5000, 10)
# test_x.shape = (10000, 1, 28, 28)
# test_y.shape = (10000, 10)

# %%
config['save_dir'] = SAVE_DIR[:-1]+'_no_l2/'
net = []
inputs = np.random.randn(config['batch_size'], 1, 28, 28)
net += [Convolution(inputs, 16, 5, "conv1")]
net += [MaxPooling(net[-1], "pool1")]
net += [ReLU(net[-1], "relu1")]
net += [Convolution(net[-1], 32, 5, "conv2")]
net += [MaxPooling(net[-1], "pool2")]
net += [ReLU(net[-1], "relu2")]
# out = 7x7
net += [Flatten(net[-1], "flatten3")]
net += [FC(net[-1], 512, "fc3")]
net += [ReLU(net[-1], "relu3")]
net += [FC(net[-1], 10, "logits")]

loss = SoftmaxCrossEntropyWithLogits()


train(train_x, train_y, valid_x, valid_y, net, loss, config)
evaluate("Test", test_x, test_y, net, loss, config)
pickle.dump( net, open( "net.p", "wb" ) )
pickle.dump( loss, open( "loss.p", "wb" ) )
# Out:
# epoch 1, step 0/55000, batch loss = 2.42
# /home/josip/anaconda3/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint16
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# epoch 1, step 2500/55000, batch loss = 0.18
# epoch 1, step 5000/55000, batch loss = 0.12
# epoch 1, step 7500/55000, batch loss = 0.20
# epoch 1, step 10000/55000, batch loss = 0.04
# epoch 1, step 12500/55000, batch loss = 0.06
# epoch 1, step 15000/55000, batch loss = 0.07
# epoch 1, step 17500/55000, batch loss = 0.15
# epoch 1, step 20000/55000, batch loss = 0.25
# epoch 1, step 22500/55000, batch loss = 0.06
# epoch 1, step 25000/55000, batch loss = 0.08
# epoch 1, step 27500/55000, batch loss = 0.22
# epoch 1, step 30000/55000, batch loss = 0.08
# epoch 1, step 32500/55000, batch loss = 0.05
# epoch 1, step 35000/55000, batch loss = 0.01
# epoch 1, step 37500/55000, batch loss = 0.02
# epoch 1, step 40000/55000, batch loss = 0.12
# epoch 1, step 42500/55000, batch loss = 0.00
# epoch 1, step 45000/55000, batch loss = 0.03
# epoch 1, step 47500/55000, batch loss = 0.12
# epoch 1, step 50000/55000, batch loss = 0.25
# epoch 1, step 52500/55000, batch loss = 0.07
# Epoch 1:
# Train accuracy = 95.43
#
# Running evaluation:  Validation
# Validation accuracy = 98.30
# Validation avg loss = 0.06
# epoch 2, step 0/55000, batch loss = 0.09
# epoch 2, step 2500/55000, batch loss = 0.05
# epoch 2, step 5000/55000, batch loss = 0.03
# epoch 2, step 7500/55000, batch loss = 0.03
# epoch 2, step 10000/55000, batch loss = 0.13
# epoch 2, step 12500/55000, batch loss = 0.05
# epoch 2, step 15000/55000, batch loss = 0.01
# epoch 2, step 17500/55000, batch loss = 0.05
# epoch 2, step 20000/55000, batch loss = 0.08
# epoch 2, step 22500/55000, batch loss = 0.02
# epoch 2, step 25000/55000, batch loss = 0.16
# epoch 2, step 27500/55000, batch loss = 0.07
# epoch 2, step 30000/55000, batch loss = 0.02
# epoch 2, step 32500/55000, batch loss = 0.05
# epoch 2, step 35000/55000, batch loss = 0.01
# epoch 2, step 37500/55000, batch loss = 0.02
# epoch 2, step 40000/55000, batch loss = 0.03
# epoch 2, step 42500/55000, batch loss = 0.02
# epoch 2, step 45000/55000, batch loss = 0.08
# epoch 2, step 47500/55000, batch loss = 0.10
# epoch 2, step 50000/55000, batch loss = 0.03
# epoch 2, step 52500/55000, batch loss = 0.05
# Epoch 2:
# Train accuracy = 98.57
#
# Running evaluation:  Validation
# Validation accuracy = 98.94
# Validation avg loss = 0.04
# epoch 3, step 0/55000, batch loss = 0.02
# epoch 3, step 2500/55000, batch loss = 0.00
# epoch 3, step 5000/55000, batch loss = 0.07
# epoch 3, step 7500/55000, batch loss = 0.00
# epoch 3, step 10000/55000, batch loss = 0.03
# epoch 3, step 12500/55000, batch loss = 0.00
# epoch 3, step 15000/55000, batch loss = 0.02
# epoch 3, step 17500/55000, batch loss = 0.05
# epoch 3, step 20000/55000, batch loss = 0.01
# epoch 3, step 22500/55000, batch loss = 0.00
# epoch 3, step 25000/55000, batch loss = 0.00
# epoch 3, step 27500/55000, batch loss = 0.05
# epoch 3, step 30000/55000, batch loss = 0.00
# epoch 3, step 32500/55000, batch loss = 0.07
# epoch 3, step 35000/55000, batch loss = 0.00
# epoch 3, step 37500/55000, batch loss = 0.02
# epoch 3, step 40000/55000, batch loss = 0.01
# epoch 3, step 42500/55000, batch loss = 0.15
# epoch 3, step 45000/55000, batch loss = 0.03
# epoch 3, step 47500/55000, batch loss = 0.03
# epoch 3, step 50000/55000, batch loss = 0.00
# epoch 3, step 52500/55000, batch loss = 0.00
# Epoch 3:
# Train accuracy = 99.42
#
# Running evaluation:  Validation
# Validation accuracy = 99.12
# Validation avg loss = 0.03
# epoch 4, step 0/55000, batch loss = 0.01
# epoch 4, step 2500/55000, batch loss = 0.01
# epoch 4, step 5000/55000, batch loss = 0.00
# epoch 4, step 7500/55000, batch loss = 0.00
# epoch 4, step 10000/55000, batch loss = 0.01
# epoch 4, step 12500/55000, batch loss = 0.01
# epoch 4, step 15000/55000, batch loss = 0.01
# epoch 4, step 17500/55000, batch loss = 0.01
# epoch 4, step 20000/55000, batch loss = 0.05
# epoch 4, step 22500/55000, batch loss = 0.05
# epoch 4, step 25000/55000, batch loss = 0.00
# epoch 4, step 27500/55000, batch loss = 0.00
# epoch 4, step 30000/55000, batch loss = 0.01
# epoch 4, step 32500/55000, batch loss = 0.02
# epoch 4, step 35000/55000, batch loss = 0.03
# epoch 4, step 37500/55000, batch loss = 0.00
# epoch 4, step 40000/55000, batch loss = 0.01
# epoch 4, step 42500/55000, batch loss = 0.00
# epoch 4, step 45000/55000, batch loss = 0.18
# epoch 4, step 47500/55000, batch loss = 0.02
# epoch 4, step 50000/55000, batch loss = 0.00
# epoch 4, step 52500/55000, batch loss = 0.00
# Epoch 4:
# Train accuracy = 99.53
#
# Running evaluation:  Validation
# Validation accuracy = 99.10
# Validation avg loss = 0.03
# epoch 5, step 0/55000, batch loss = 0.08
# epoch 5, step 2500/55000, batch loss = 0.00
# epoch 5, step 5000/55000, batch loss = 0.00
# epoch 5, step 7500/55000, batch loss = 0.01
# epoch 5, step 10000/55000, batch loss = 0.01
# epoch 5, step 12500/55000, batch loss = 0.00
# epoch 5, step 15000/55000, batch loss = 0.01
# epoch 5, step 17500/55000, batch loss = 0.00
# epoch 5, step 20000/55000, batch loss = 0.04
# epoch 5, step 22500/55000, batch loss = 0.01
# epoch 5, step 25000/55000, batch loss = 0.00
# epoch 5, step 27500/55000, batch loss = 0.00
# epoch 5, step 30000/55000, batch loss = 0.07
# epoch 5, step 32500/55000, batch loss = 0.06
# epoch 5, step 35000/55000, batch loss = 0.01
# epoch 5, step 37500/55000, batch loss = 0.05
# epoch 5, step 40000/55000, batch loss = 0.07
# epoch 5, step 42500/55000, batch loss = 0.00
# epoch 5, step 45000/55000, batch loss = 0.01
# epoch 5, step 47500/55000, batch loss = 0.00
# epoch 5, step 50000/55000, batch loss = 0.00
# epoch 5, step 52500/55000, batch loss = 0.00
# Epoch 5:
# Train accuracy = 99.58
#
# Running evaluation:  Validation
# Validation accuracy = 99.14
# Validation avg loss = 0.03
# Running evaluation:  Test
# Test accuracy = 99.22
# Test avg loss = 0.02

# %%
'''
...
Train accuracy = 99.57
epoch 8, step 50250/55000, batch loss = 0.00
epoch 8, step 50500/55000, batch loss = 0.00
epoch 8, step 50750/55000, batch loss = 0.01
epoch 8, step 51000/55000, batch loss = 0.01
epoch 8, step 51250/55000, batch loss = 0.01
epoch 8, step 51500/55000, batch loss = 0.01
epoch 8, step 51750/55000, batch loss = 0.00
epoch 8, step 52000/55000, batch loss = 0.01
epoch 8, step 52250/55000, batch loss = 0.08
epoch 8, step 52500/55000, batch loss = 0.03
Train accuracy = 99.57
epoch 8, step 52750/55000, batch loss = 0.01
epoch 8, step 53000/55000, batch loss = 0.02
epoch 8, step 53250/55000, batch loss = 0.03
epoch 8, step 53500/55000, batch loss = 0.00
epoch 8, step 53750/55000, batch loss = 0.05
epoch 8, step 54000/55000, batch loss = 0.00
epoch 8, step 54250/55000, batch loss = 0.00
epoch 8, step 54500/55000, batch loss = 0.00
epoch 8, step 54750/55000, batch loss = 0.01
Train accuracy = 99.57

Running evaluation:  Validation
Validation accuracy = 99.18
Validation avg loss = 0.03


Running evaluation:  Test
Test accuracy = 99.14
Test avg loss = 0.02
'''

# %%
net = pickle.load( open( "net.p", "rb" ) )
evaluate("Test", test_x, test_y, net, loss, config)
# Out:
# Running evaluation:  Test
# Test accuracy = 99.14
# Test avg loss = 0.02

# %% [markdown]
# # train_l2reg.py

# %%
config = {}
config['max_epochs'] = 5
config['batch_size'] = 50
config['save_dir'] = SAVE_DIR
config['weight_decay'] = 1e-3
config['lr_policy'] = {1:{'lr':1e-1}, 3:{'lr':1e-2}, 5:{'lr':1e-3}, 7:{'lr':1e-4}}

#np.random.seed(100) 
np.random.seed(int(time.time() * 1e6) % 2**31)
dataset = input_data.read_data_sets(DATA_DIR, one_hot=True)
train_x = dataset.train.images
train_x = train_x.reshape([-1, 1, 28, 28])
train_y = dataset.train.labels
valid_x = dataset.validation.images
valid_x = valid_x.reshape([-1, 1, 28, 28])
valid_y = dataset.validation.labels
test_x = dataset.test.images
test_x = test_x.reshape([-1, 1, 28, 28])
test_y = dataset.test.labels
train_mean = train_x.mean()
train_x -= train_mean
valid_x -= train_mean
test_x -= train_mean
# Out:
# Extracting /home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/train-images-idx3-ubyte.gz
# Extracting /home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/train-labels-idx1-ubyte.gz
# Extracting /home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/t10k-images-idx3-ubyte.gz
# Extracting /home/josip/Documents/DU/LAB2/fer-deep-learning/lab2/datasets/MNIST/t10k-labels-idx1-ubyte.gz

# %%
weight_decay = 1e-3
config['save_dir'] = SAVE_DIR[:-1]+'_l2_1e-3/'
net = []
regularizers = []
inputs = np.random.randn(config['batch_size'], 1, 28, 28)
net += [Convolution(inputs, 16, 5, "conv1")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'conv1_l2reg')]
net += [MaxPooling(net[-1], "pool1")]
net += [ReLU(net[-1], "relu1")]
net += [Convolution(net[-1], 32, 5, "conv2")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'conv2_l2reg')]
net += [MaxPooling(net[-1], "pool2")]
net += [ReLU(net[-1], "relu2")]
## 7x7
net += [Flatten(net[-1], "flatten3")]
net += [FC(net[-1], 512, "fc3")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'fc3_l2reg')]
net += [ReLU(net[-1], "relu3")]
net += [FC(net[-1], 10, "logits")]

data_loss = SoftmaxCrossEntropyWithLogits()
loss = RegularizedLoss(data_loss, regularizers)

train(train_x, train_y, valid_x, valid_y, net, loss, config)
evaluate("Test", test_x, test_y, net, loss, config)

pickle.dump( net, open( "net_l2_1e-3.p", "wb" ) )
pickle.dump( loss, open( "loss_l2_1e-3.p", "wb" ) )
# Out:
# epoch 1, step 0/55000, batch loss = 2.86
# /home/josip/anaconda3/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint16
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# epoch 1, step 2500/55000, batch loss = 0.79
# epoch 1, step 5000/55000, batch loss = 0.71
# epoch 1, step 7500/55000, batch loss = 0.70
# epoch 1, step 10000/55000, batch loss = 0.62
# epoch 1, step 12500/55000, batch loss = 0.58
# epoch 1, step 15000/55000, batch loss = 0.67
# epoch 1, step 17500/55000, batch loss = 0.46
# epoch 1, step 20000/55000, batch loss = 0.47
# epoch 1, step 22500/55000, batch loss = 0.49
# epoch 1, step 25000/55000, batch loss = 0.57
# epoch 1, step 27500/55000, batch loss = 0.63
# epoch 1, step 30000/55000, batch loss = 0.42
# epoch 1, step 32500/55000, batch loss = 0.45
# epoch 1, step 35000/55000, batch loss = 0.49
# epoch 1, step 37500/55000, batch loss = 0.44
# epoch 1, step 40000/55000, batch loss = 0.45
# epoch 1, step 42500/55000, batch loss = 0.44
# epoch 1, step 45000/55000, batch loss = 0.54
# epoch 1, step 47500/55000, batch loss = 0.38
# epoch 1, step 50000/55000, batch loss = 0.39
# epoch 1, step 52500/55000, batch loss = 0.52
# Epoch 1:
# Train accuracy = 94.82
#
# Running evaluation:  Validation
# Validation accuracy = 98.40
# Validation avg loss = 0.42
# epoch 2, step 0/55000, batch loss = 0.41
# epoch 2, step 2500/55000, batch loss = 0.45
# epoch 2, step 5000/55000, batch loss = 0.39
# epoch 2, step 7500/55000, batch loss = 0.44
# epoch 2, step 10000/55000, batch loss = 0.36
# epoch 2, step 12500/55000, batch loss = 0.44
# epoch 2, step 15000/55000, batch loss = 0.47
# epoch 2, step 17500/55000, batch loss = 0.39
# epoch 2, step 20000/55000, batch loss = 0.46
# epoch 2, step 22500/55000, batch loss = 0.36
# epoch 2, step 25000/55000, batch loss = 0.41
# epoch 2, step 27500/55000, batch loss = 0.38
# epoch 2, step 30000/55000, batch loss = 0.40
# epoch 2, step 32500/55000, batch loss = 0.33
# epoch 2, step 35000/55000, batch loss = 0.41
# epoch 2, step 37500/55000, batch loss = 0.45
# epoch 2, step 40000/55000, batch loss = 0.40
# epoch 2, step 42500/55000, batch loss = 0.43
# epoch 2, step 45000/55000, batch loss = 0.33
# epoch 2, step 47500/55000, batch loss = 0.33
# epoch 2, step 50000/55000, batch loss = 0.32
# epoch 2, step 52500/55000, batch loss = 0.38
# Epoch 2:
# Train accuracy = 98.38
#
# Running evaluation:  Validation
# Validation accuracy = 98.52
# Validation avg loss = 0.35
# epoch 3, step 0/55000, batch loss = 0.30
# epoch 3, step 2500/55000, batch loss = 0.35
# epoch 3, step 5000/55000, batch loss = 0.33
# epoch 3, step 7500/55000, batch loss = 0.32
# epoch 3, step 10000/55000, batch loss = 0.36
# epoch 3, step 12500/55000, batch loss = 0.32
# epoch 3, step 15000/55000, batch loss = 0.30
# epoch 3, step 17500/55000, batch loss = 0.30
# epoch 3, step 20000/55000, batch loss = 0.30
# epoch 3, step 22500/55000, batch loss = 0.33
# epoch 3, step 25000/55000, batch loss = 0.33
# epoch 3, step 27500/55000, batch loss = 0.33
# epoch 3, step 30000/55000, batch loss = 0.30
# epoch 3, step 32500/55000, batch loss = 0.30
# epoch 3, step 35000/55000, batch loss = 0.30
# epoch 3, step 37500/55000, batch loss = 0.30
# epoch 3, step 40000/55000, batch loss = 0.31
# epoch 3, step 42500/55000, batch loss = 0.33
# epoch 3, step 45000/55000, batch loss = 0.31
# epoch 3, step 47500/55000, batch loss = 0.31
# epoch 3, step 50000/55000, batch loss = 0.30
# epoch 3, step 52500/55000, batch loss = 0.30
# Epoch 3:
# Train accuracy = 99.26
#
# Running evaluation:  Validation
# Validation accuracy = 99.10
# Validation avg loss = 0.33
# epoch 4, step 0/55000, batch loss = 0.30
# epoch 4, step 2500/55000, batch loss = 0.33
# epoch 4, step 5000/55000, batch loss = 0.30
# epoch 4, step 7500/55000, batch loss = 0.34
# epoch 4, step 10000/55000, batch loss = 0.30
# epoch 4, step 12500/55000, batch loss = 0.30
# epoch 4, step 15000/55000, batch loss = 0.30
# epoch 4, step 17500/55000, batch loss = 0.32
# epoch 4, step 20000/55000, batch loss = 0.29
# epoch 4, step 22500/55000, batch loss = 0.33
# epoch 4, step 25000/55000, batch loss = 0.32
# epoch 4, step 27500/55000, batch loss = 0.29
# epoch 4, step 30000/55000, batch loss = 0.31
# epoch 4, step 32500/55000, batch loss = 0.35
# epoch 4, step 35000/55000, batch loss = 0.30
# epoch 4, step 37500/55000, batch loss = 0.30
# epoch 4, step 40000/55000, batch loss = 0.29
# epoch 4, step 42500/55000, batch loss = 0.29
# epoch 4, step 45000/55000, batch loss = 0.29
# epoch 4, step 47500/55000, batch loss = 0.31
# epoch 4, step 50000/55000, batch loss = 0.36
# epoch 4, step 52500/55000, batch loss = 0.29
# Epoch 4:
# Train accuracy = 99.36
#
# Running evaluation:  Validation
# Validation accuracy = 99.08
# Validation avg loss = 0.32
# epoch 5, step 0/55000, batch loss = 0.33
# epoch 5, step 2500/55000, batch loss = 0.30
# epoch 5, step 5000/55000, batch loss = 0.34
# epoch 5, step 7500/55000, batch loss = 0.29
# epoch 5, step 10000/55000, batch loss = 0.32
# epoch 5, step 12500/55000, batch loss = 0.32
# epoch 5, step 15000/55000, batch loss = 0.29
# epoch 5, step 17500/55000, batch loss = 0.30
# epoch 5, step 20000/55000, batch loss = 0.36
# epoch 5, step 22500/55000, batch loss = 0.31
# epoch 5, step 25000/55000, batch loss = 0.29
# epoch 5, step 27500/55000, batch loss = 0.29
# epoch 5, step 30000/55000, batch loss = 0.30
# epoch 5, step 32500/55000, batch loss = 0.30
# epoch 5, step 35000/55000, batch loss = 0.30
# epoch 5, step 37500/55000, batch loss = 0.31
# epoch 5, step 40000/55000, batch loss = 0.31
# epoch 5, step 42500/55000, batch loss = 0.29
# epoch 5, step 45000/55000, batch loss = 0.31
# epoch 5, step 47500/55000, batch loss = 0.29
# epoch 5, step 50000/55000, batch loss = 0.30
# epoch 5, step 52500/55000, batch loss = 0.29
# Epoch 5:
# Train accuracy = 99.40
#
# Running evaluation:  Validation
# Validation accuracy = 99.10
# Validation avg loss = 0.32
# Running evaluation:  Test
# Test accuracy = 99.05
# Test avg loss = 0.31

# %%
weight_decay = 1e-2
config['save_dir'] = SAVE_DIR[:-1]+'_l2_1e-2/'
net = []
regularizers = []
inputs = np.random.randn(config['batch_size'], 1, 28, 28)
net += [Convolution(inputs, 16, 5, "conv1")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'conv1_l2reg')]
net += [MaxPooling(net[-1], "pool1")]
net += [ReLU(net[-1], "relu1")]
net += [Convolution(net[-1], 32, 5, "conv2")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'conv2_l2reg')]
net += [MaxPooling(net[-1], "pool2")]
net += [ReLU(net[-1], "relu2")]
## 7x7
net += [Flatten(net[-1], "flatten3")]
net += [FC(net[-1], 512, "fc3")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'fc3_l2reg')]
net += [ReLU(net[-1], "relu3")]
net += [FC(net[-1], 10, "logits")]

data_loss = SoftmaxCrossEntropyWithLogits()
loss = RegularizedLoss(data_loss, regularizers)

train(train_x, train_y, valid_x, valid_y, net, loss, config)
evaluate("Test", test_x, test_y, net, loss, config)

pickle.dump( net, open( "net_l2_1e-2.p", "wb" ) )
pickle.dump( loss, open( "loss_l2_1e-2.p", "wb" ) )
# Out:
# epoch 1, step 0/55000, batch loss = 6.79
# /home/josip/anaconda3/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint16
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# epoch 1, step 2500/55000, batch loss = 4.27
# epoch 1, step 5000/55000, batch loss = 3.78
# epoch 1, step 7500/55000, batch loss = 3.58
# epoch 1, step 10000/55000, batch loss = 3.07
# epoch 1, step 12500/55000, batch loss = 2.88
# epoch 1, step 15000/55000, batch loss = 2.51
# epoch 1, step 17500/55000, batch loss = 2.35
# epoch 1, step 20000/55000, batch loss = 2.11
# epoch 1, step 22500/55000, batch loss = 1.96
# epoch 1, step 25000/55000, batch loss = 1.91
# epoch 1, step 27500/55000, batch loss = 1.63
# epoch 1, step 30000/55000, batch loss = 1.43
# epoch 1, step 32500/55000, batch loss = 1.41
# epoch 1, step 35000/55000, batch loss = 1.20
# epoch 1, step 37500/55000, batch loss = 1.18
# epoch 1, step 40000/55000, batch loss = 1.07
# epoch 1, step 42500/55000, batch loss = 1.04
# epoch 1, step 45000/55000, batch loss = 0.84
# epoch 1, step 47500/55000, batch loss = 0.79
# epoch 1, step 50000/55000, batch loss = 0.83
# epoch 1, step 52500/55000, batch loss = 0.79
# Epoch 1:
# Train accuracy = 94.94
#
# Running evaluation:  Validation
# Validation accuracy = 97.72
# Validation avg loss = 0.66
# epoch 2, step 0/55000, batch loss = 0.75
# epoch 2, step 2500/55000, batch loss = 0.71
# epoch 2, step 5000/55000, batch loss = 0.58
# epoch 2, step 7500/55000, batch loss = 0.71
# epoch 2, step 10000/55000, batch loss = 0.46
# epoch 2, step 12500/55000, batch loss = 0.47
# epoch 2, step 15000/55000, batch loss = 0.46
# epoch 2, step 17500/55000, batch loss = 0.38
# epoch 2, step 20000/55000, batch loss = 0.37
# epoch 2, step 22500/55000, batch loss = 0.49
# epoch 2, step 25000/55000, batch loss = 0.34
# epoch 2, step 27500/55000, batch loss = 0.29
# epoch 2, step 30000/55000, batch loss = 0.31
# epoch 2, step 32500/55000, batch loss = 0.47
# epoch 2, step 35000/55000, batch loss = 0.35
# epoch 2, step 37500/55000, batch loss = 0.27
# epoch 2, step 40000/55000, batch loss = 0.33
# epoch 2, step 42500/55000, batch loss = 0.21
# epoch 2, step 45000/55000, batch loss = 0.33
# epoch 2, step 47500/55000, batch loss = 0.24
# epoch 2, step 50000/55000, batch loss = 0.27
# epoch 2, step 52500/55000, batch loss = 0.27
# Epoch 2:
# Train accuracy = 97.54
#
# Running evaluation:  Validation
# Validation accuracy = 98.22
# Validation avg loss = 0.22
# epoch 3, step 0/55000, batch loss = 0.27
# epoch 3, step 2500/55000, batch loss = 0.20
# epoch 3, step 5000/55000, batch loss = 0.23
# epoch 3, step 7500/55000, batch loss = 0.18
# epoch 3, step 10000/55000, batch loss = 0.17
# epoch 3, step 12500/55000, batch loss = 0.22
# epoch 3, step 15000/55000, batch loss = 0.17
# epoch 3, step 17500/55000, batch loss = 0.16
# epoch 3, step 20000/55000, batch loss = 0.18
# epoch 3, step 22500/55000, batch loss = 0.18
# epoch 3, step 25000/55000, batch loss = 0.16
# epoch 3, step 27500/55000, batch loss = 0.17
# epoch 3, step 30000/55000, batch loss = 0.25
# epoch 3, step 32500/55000, batch loss = 0.16
# epoch 3, step 35000/55000, batch loss = 0.16
# epoch 3, step 37500/55000, batch loss = 0.17
# epoch 3, step 40000/55000, batch loss = 0.15
# epoch 3, step 42500/55000, batch loss = 0.18
# epoch 3, step 45000/55000, batch loss = 0.21
# epoch 3, step 47500/55000, batch loss = 0.16
# epoch 3, step 50000/55000, batch loss = 0.21
# epoch 3, step 52500/55000, batch loss = 0.19
# Epoch 3:
# Train accuracy = 98.59
#
# Running evaluation:  Validation
# Validation accuracy = 98.68
# Validation avg loss = 0.19
# epoch 4, step 0/55000, batch loss = 0.31
# epoch 4, step 2500/55000, batch loss = 0.16
# epoch 4, step 5000/55000, batch loss = 0.15
# epoch 4, step 7500/55000, batch loss = 0.27
# epoch 4, step 10000/55000, batch loss = 0.17
# epoch 4, step 12500/55000, batch loss = 0.15
# epoch 4, step 15000/55000, batch loss = 0.16
# epoch 4, step 17500/55000, batch loss = 0.17
# epoch 4, step 20000/55000, batch loss = 0.22
# epoch 4, step 22500/55000, batch loss = 0.18
# epoch 4, step 25000/55000, batch loss = 0.17
# epoch 4, step 27500/55000, batch loss = 0.17
# epoch 4, step 30000/55000, batch loss = 0.18
# epoch 4, step 32500/55000, batch loss = 0.15
# epoch 4, step 35000/55000, batch loss = 0.19
# epoch 4, step 37500/55000, batch loss = 0.14
# epoch 4, step 40000/55000, batch loss = 0.15
# epoch 4, step 42500/55000, batch loss = 0.15
# epoch 4, step 45000/55000, batch loss = 0.15
# epoch 4, step 47500/55000, batch loss = 0.14
# epoch 4, step 50000/55000, batch loss = 0.16
# epoch 4, step 52500/55000, batch loss = 0.30
# Epoch 4:
# Train accuracy = 98.66
#
# Running evaluation:  Validation
# Validation accuracy = 98.66
# Validation avg loss = 0.17
# epoch 5, step 0/55000, batch loss = 0.14
# epoch 5, step 2500/55000, batch loss = 0.18
# epoch 5, step 5000/55000, batch loss = 0.16
# epoch 5, step 7500/55000, batch loss = 0.16
# epoch 5, step 10000/55000, batch loss = 0.16
# epoch 5, step 12500/55000, batch loss = 0.17
# epoch 5, step 15000/55000, batch loss = 0.21
# epoch 5, step 17500/55000, batch loss = 0.14
# epoch 5, step 20000/55000, batch loss = 0.13
# epoch 5, step 22500/55000, batch loss = 0.14
# epoch 5, step 25000/55000, batch loss = 0.21
# epoch 5, step 27500/55000, batch loss = 0.15
# epoch 5, step 30000/55000, batch loss = 0.26
# epoch 5, step 32500/55000, batch loss = 0.16
# epoch 5, step 35000/55000, batch loss = 0.28
# epoch 5, step 37500/55000, batch loss = 0.13
# epoch 5, step 40000/55000, batch loss = 0.16
# epoch 5, step 42500/55000, batch loss = 0.15
# epoch 5, step 45000/55000, batch loss = 0.17
# epoch 5, step 47500/55000, batch loss = 0.14
# epoch 5, step 50000/55000, batch loss = 0.17
# epoch 5, step 52500/55000, batch loss = 0.15
# Epoch 5:
# Train accuracy = 98.80
#
# Running evaluation:  Validation
# Validation accuracy = 98.78
# Validation avg loss = 0.17
# Running evaluation:  Test
# Test accuracy = 98.69
# Test avg loss = 0.17

# %%
weight_decay = 1e-1
config['save_dir'] = SAVE_DIR[:-1]+'_l2_1e-1/'
net = []
regularizers = []
inputs = np.random.randn(config['batch_size'], 1, 28, 28)
net += [Convolution(inputs, 16, 5, "conv1")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'conv1_l2reg')]
net += [MaxPooling(net[-1], "pool1")]
net += [ReLU(net[-1], "relu1")]
net += [Convolution(net[-1], 32, 5, "conv2")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'conv2_l2reg')]
net += [MaxPooling(net[-1], "pool2")]
net += [ReLU(net[-1], "relu2")]
## 7x7
net += [Flatten(net[-1], "flatten3")]
net += [FC(net[-1], 512, "fc3")]
regularizers += [L2Regularizer(net[-1].weights, weight_decay, 'fc3_l2reg')]
net += [ReLU(net[-1], "relu3")]
net += [FC(net[-1], 10, "logits")]

data_loss = SoftmaxCrossEntropyWithLogits()
loss = RegularizedLoss(data_loss, regularizers)

train(train_x, train_y, valid_x, valid_y, net, loss, config)
evaluate("Test", test_x, test_y, net, loss, config)

pickle.dump( net, open( "net_l2_1e-1.p", "wb" ) )
pickle.dump( loss, open( "loss_l2_1e-1.p", "wb" ) )
# Out:
# epoch 1, step 0/55000, batch loss = 45.94
# /home/josip/anaconda3/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint16
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# epoch 1, step 2500/55000, batch loss = 16.70
# epoch 1, step 5000/55000, batch loss = 6.95
# epoch 1, step 7500/55000, batch loss = 2.95
# epoch 1, step 10000/55000, batch loss = 1.47
# epoch 1, step 12500/55000, batch loss = 0.95
# epoch 1, step 15000/55000, batch loss = 0.84
# epoch 1, step 17500/55000, batch loss = 0.85
# epoch 1, step 20000/55000, batch loss = 0.97
# epoch 1, step 22500/55000, batch loss = 0.73
# epoch 1, step 25000/55000, batch loss = 0.76
# epoch 1, step 27500/55000, batch loss = 0.77
# epoch 1, step 30000/55000, batch loss = 0.85
# epoch 1, step 32500/55000, batch loss = 0.66
# epoch 1, step 35000/55000, batch loss = 0.60
# epoch 1, step 37500/55000, batch loss = 0.71
# epoch 1, step 40000/55000, batch loss = 0.70
# epoch 1, step 42500/55000, batch loss = 0.75
# epoch 1, step 45000/55000, batch loss = 0.88
# epoch 1, step 47500/55000, batch loss = 0.63
# epoch 1, step 50000/55000, batch loss = 0.64
# epoch 1, step 52500/55000, batch loss = 0.71
# Epoch 1:
# Train accuracy = 88.74
#
# Running evaluation:  Validation
# Validation accuracy = 93.08
# Validation avg loss = 0.62
# epoch 2, step 0/55000, batch loss = 0.65
# epoch 2, step 2500/55000, batch loss = 0.61
# epoch 2, step 5000/55000, batch loss = 0.75
# epoch 2, step 7500/55000, batch loss = 0.52
# epoch 2, step 10000/55000, batch loss = 0.68
# epoch 2, step 12500/55000, batch loss = 0.63
# epoch 2, step 15000/55000, batch loss = 1.33
# epoch 2, step 17500/55000, batch loss = 0.73
# epoch 2, step 20000/55000, batch loss = 0.66
# epoch 2, step 22500/55000, batch loss = 0.58
# epoch 2, step 25000/55000, batch loss = 0.66
# epoch 2, step 27500/55000, batch loss = 0.57
# epoch 2, step 30000/55000, batch loss = 0.66
# epoch 2, step 32500/55000, batch loss = 0.57
# epoch 2, step 35000/55000, batch loss = 0.62
# epoch 2, step 37500/55000, batch loss = 0.63
# epoch 2, step 40000/55000, batch loss = 0.52
# epoch 2, step 42500/55000, batch loss = 0.77
# epoch 2, step 45000/55000, batch loss = 0.49
# epoch 2, step 47500/55000, batch loss = 0.70
# epoch 2, step 50000/55000, batch loss = 0.62
# epoch 2, step 52500/55000, batch loss = 0.64
# Epoch 2:
# Train accuracy = 91.25
#
# Running evaluation:  Validation
# Validation accuracy = 86.52
# Validation avg loss = 1.07
# epoch 3, step 0/55000, batch loss = 1.00
# epoch 3, step 2500/55000, batch loss = 0.65
# epoch 3, step 5000/55000, batch loss = 0.77
# epoch 3, step 7500/55000, batch loss = 0.59
# epoch 3, step 10000/55000, batch loss = 0.55
# epoch 3, step 12500/55000, batch loss = 0.67
# epoch 3, step 15000/55000, batch loss = 0.63
# epoch 3, step 17500/55000, batch loss = 0.58
# epoch 3, step 20000/55000, batch loss = 0.61
# epoch 3, step 22500/55000, batch loss = 0.64
# epoch 3, step 25000/55000, batch loss = 0.52
# epoch 3, step 27500/55000, batch loss = 0.43
# epoch 3, step 30000/55000, batch loss = 0.45
# epoch 3, step 32500/55000, batch loss = 0.51
# epoch 3, step 35000/55000, batch loss = 0.45
# epoch 3, step 37500/55000, batch loss = 0.49
# epoch 3, step 40000/55000, batch loss = 0.51
# epoch 3, step 42500/55000, batch loss = 0.42
# epoch 3, step 45000/55000, batch loss = 0.57
# epoch 3, step 47500/55000, batch loss = 0.57
# epoch 3, step 50000/55000, batch loss = 0.38
# epoch 3, step 52500/55000, batch loss = 0.51
# Epoch 3:
# Train accuracy = 94.91
#
# Running evaluation:  Validation
# Validation accuracy = 95.62
# Validation avg loss = 0.46
# epoch 4, step 0/55000, batch loss = 0.40
# epoch 4, step 2500/55000, batch loss = 0.58
# epoch 4, step 5000/55000, batch loss = 0.44
# epoch 4, step 7500/55000, batch loss = 0.47
# epoch 4, step 10000/55000, batch loss = 0.53
# epoch 4, step 12500/55000, batch loss = 0.52
# epoch 4, step 15000/55000, batch loss = 0.54
# epoch 4, step 17500/55000, batch loss = 0.43
# epoch 4, step 20000/55000, batch loss = 0.53
# epoch 4, step 22500/55000, batch loss = 0.43
# epoch 4, step 25000/55000, batch loss = 0.41
# epoch 4, step 27500/55000, batch loss = 0.42
# epoch 4, step 30000/55000, batch loss = 0.51
# epoch 4, step 32500/55000, batch loss = 0.42
# epoch 4, step 35000/55000, batch loss = 0.48
# epoch 4, step 37500/55000, batch loss = 0.51
# epoch 4, step 40000/55000, batch loss = 0.57
# epoch 4, step 42500/55000, batch loss = 0.37
# epoch 4, step 45000/55000, batch loss = 0.40
# epoch 4, step 47500/55000, batch loss = 0.53
# epoch 4, step 50000/55000, batch loss = 0.51
# epoch 4, step 52500/55000, batch loss = 0.37
# Epoch 4:
# Train accuracy = 95.40
#
# Running evaluation:  Validation
# Validation accuracy = 96.04
# Validation avg loss = 0.44
# epoch 5, step 0/55000, batch loss = 0.45
# epoch 5, step 2500/55000, batch loss = 0.36
# epoch 5, step 5000/55000, batch loss = 0.35
# epoch 5, step 7500/55000, batch loss = 0.39
# epoch 5, step 10000/55000, batch loss = 0.37
# epoch 5, step 12500/55000, batch loss = 0.41
# epoch 5, step 15000/55000, batch loss = 0.40
# epoch 5, step 17500/55000, batch loss = 0.39
# epoch 5, step 20000/55000, batch loss = 0.50
# epoch 5, step 22500/55000, batch loss = 0.36
# epoch 5, step 25000/55000, batch loss = 0.37
# epoch 5, step 27500/55000, batch loss = 0.39
# epoch 5, step 30000/55000, batch loss = 0.42
# epoch 5, step 32500/55000, batch loss = 0.47
# epoch 5, step 35000/55000, batch loss = 0.43
# epoch 5, step 37500/55000, batch loss = 0.41
# epoch 5, step 40000/55000, batch loss = 0.35
# epoch 5, step 42500/55000, batch loss = 0.43
# epoch 5, step 45000/55000, batch loss = 0.42
# epoch 5, step 47500/55000, batch loss = 0.43
# epoch 5, step 50000/55000, batch loss = 0.43
# epoch 5, step 52500/55000, batch loss = 0.39
# Epoch 5:
# Train accuracy = 95.85
#
# Running evaluation:  Validation
# Validation accuracy = 96.20
# Validation avg loss = 0.43
# Running evaluation:  Test
# Test accuracy = 96.37
# Test avg loss = 0.42

# %%
net = pickle.load( open( "net.p", "rb" ) )
loss = pickle.load( open( "loss.p", "rb" ) )
evaluate("Test", test_x, test_y, net, loss, config)
# Out:
# Running evaluation:  Test
# Test accuracy = 99.22
# Test avg loss = 0.02

# %%
net_l2_min3 = pickle.load( open( "net_l2_1e-3.p", "rb" ) )
loss_l2_min3 = pickle.load( open( "loss_l2_1e-3.p", "rb" ) )
evaluate("Test", test_x, test_y, net_l2_min3, loss_l2_min3, config)
# Out:
# Running evaluation:  Test
# Test accuracy = 99.05
# Test avg loss = 0.31

# %%
net_l2_min2 = pickle.load( open( "net_l2_1e-2.p", "rb" ) )
loss_l2_min2 = pickle.load( open( "loss_l2_1e-2.p", "rb" ) )
evaluate("Test", test_x, test_y, net_l2_min2, loss_l2_min2, config)
# Out:
# Running evaluation:  Test
# Test accuracy = 98.69
# Test avg loss = 0.17

# %%
net_l2_min1 = pickle.load( open( "net_l2_1e-1.p", "rb" ) )
loss_l2_min1 = pickle.load( open( "loss_l2_1e-1.p", "rb" ) )
evaluate("Test", test_x, test_y, net_l2_min1, loss_l2_min1, config)
# Out:
# Running evaluation:  Test
# Test accuracy = 96.37
# Test avg loss = 0.42

# %% [markdown]
# # check_grads.py

# %%
def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def eval_numerical_gradient(f, x, df, h=1e-5):
  """
  Evaluate a numeric gradient for a function that accepts a numpy
  array and returns a numpy array.
  - f should be a function that takes a single argument
  - x is the point (numpy array) to evaluate the gradient at
  """
  grad = np.zeros_like(x)
  it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
  while not it.finished:
    ix = it.multi_index
    
    oldval = x[ix]
    x[ix] = oldval + h
    # evaluate f(x + h)
    pos = f(x.copy()).copy()
    x[ix] = oldval - h
    # evaluate f(x - h)
    neg = f(x.copy()).copy()
    x[ix] = oldval
    
    # compute the partial derivative with centered formula
    grad[ix] = np.sum((pos - neg) * df) / (2 * h)
    # step to next dimension
    it.iternext()
  return grad

def check_grad_inputs(layer, x, grad_out):
  """
  Args:
    layer: Layer object
    x: ndarray tensor input data
    grad_out: ndarray tensor gradient from the next layer
  """
  grad_x_num = eval_numerical_gradient(layer.forward, x, grad_out)
  grad_x = layer.backward_inputs(grad_out)
  print("Relative error = ", rel_error(grad_x_num, grad_x))
  print("Error norm = ", np.linalg.norm(grad_x_num - grad_x))

def check_grad_params(layer, x, w, b, grad_out):
  """
  Args:
    layer: Layer object
    x: ndarray tensor input data
    w: ndarray tensor layer weights
    b: ndarray tensor layer biases
    grad_out: ndarray tensor gradient from the next layer
  """
  func = lambda params: layer.forward(x)
  grad_w_num = eval_numerical_gradient(func, w, grad_out)
  grad_b_num = eval_numerical_gradient(func, b, grad_out)
  grads = layer.backward_params(grad_out)
  grad_w = grads[0][1]
  grad_b = grads[1][1]
  print("Check weights:")
  print("Relative error = ", rel_error(grad_w_num, grad_w))
  print("Error norm = ", np.linalg.norm(grad_w_num - grad_w))
  print("Check biases:")
  print("Relative error = ", rel_error(grad_b_num, grad_b))
  print("Error norm = ", np.linalg.norm(grad_b_num - grad_b))

print("Convolution")
x = np.random.randn(4, 3, 5, 5)
grad_out = np.random.randn(4, 2, 5, 5)
conv = Convolution(x, 2, 3, "conv1")
print("Check grad wrt input")
check_grad_inputs(conv, x, grad_out)
print("Check grad wrt params")
check_grad_params(conv, x, conv.weights, conv.bias, grad_out)

print("\nMaxPooling")
x = np.random.randn(5, 4, 8, 8)
grad_out = np.random.randn(5, 4, 4, 4)
pool = MaxPooling(x, "pool", 2, 2)
print("Check grad wrt input")
check_grad_inputs(pool, x, grad_out)

print("\nReLU")
x = np.random.randn(4, 3, 5, 5)
grad_out = np.random.randn(4, 3, 5, 5)
relu = ReLU(x, "relu")
print("Check grad wrt input")
check_grad_inputs(relu, x, grad_out)

print("\nFC")
x = np.random.randn(20, 40)
grad_out = np.random.randn(20, 30)
fc = FC(x, 30, "fc")
print("Check grad wrt input")
check_grad_inputs(fc, x, grad_out)
print("Check grad wrt params")
check_grad_params(fc, x, fc.weights, fc.bias, grad_out)

print("\nSoftmaxCrossEntropyWithLogits")
x = np.random.randn(50, 20)
y = np.zeros([50, 20])
y[:,0] = 1
loss = SoftmaxCrossEntropyWithLogits()
grad_x_num = eval_numerical_gradient(lambda x: loss.forward(x, y), x, 1)
out = loss.forward(x, y)
grad_x = loss.backward_inputs(x, y)
print("Relative error = ", rel_error(grad_x_num, grad_x))
print("Error norm = ", np.linalg.norm(grad_x_num - grad_x))
# Out:
# Convolution
# Check grad wrt input
# Relative error =  3.74108102848e-09
# Error norm =  3.47454893425e-10
# Check grad wrt params
# Check weights:
# Relative error =  8.97442960981e-11
# Error norm =  3.88929640763e-10
# Check biases:
# Relative error =  4.79653376197e-12
# Error norm =  1.31155023191e-10
#
# MaxPooling
# Check grad wrt input
# Relative error =  3.27563392672e-12
# Error norm =  9.66360060572e-11
#
# ReLU
# Check grad wrt input
# Relative error =  3.27564921936e-12
# Error norm =  5.6505467444e-11
#
# FC
# Check grad wrt input
# Relative error =  3.71087231461e-08
# Error norm =  1.1229481401e-09
# Check grad wrt params
# Check weights:
# Relative error =  3.53374698581e-09
# Error norm =  1.08406383091e-09
# Check biases:
# Relative error =  3.8434497075e-11
# Error norm =  1.14787039982e-10
#
# SoftmaxCrossEntropyWithLogits
# Relative error =  2.97624241623e-07
# Error norm =  4.85167546284e-10

# %% [markdown]
# # tf

# %%
num_examples = train_x.shape[0]
batch_size = config['batch_size']
max_epochs = config['max_epochs']
num_batches = num_examples // batch_size

def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

mnist = dataset

with tf.Graph().as_default():
    x = tf.placeholder("float", shape=[None, 784])
    y_ = tf.placeholder("float", shape=[None, 10])

    W_conv1 = weight_variable([5, 5, 1, 16])
    b_conv1 = bias_variable([16])
    x_image = tf.reshape(x, [-1, 28, 28, 1])
    h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
    h_pool1 = max_pool_2x2(h_conv1)

    W_conv2 = weight_variable([5, 5, 16, 32])
    b_conv2 = bias_variable([32])
    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
    h_pool2 = max_pool_2x2(h_conv2)

    W_fc1 = weight_variable([1568, 512])
    b_fc1 = bias_variable([512])
    h_pool2_flat = tf.reshape(h_pool2, [-1, 1568])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

    W_fc2 = weight_variable([512, 10])
    b_fc2 = bias_variable([10])

    y_conv = tf.nn.softmax(tf.matmul(h_fc1, W_fc2) + b_fc2)
    
    regularizers = (tf.nn.l2_loss(W_fc1) + tf.nn.l2_loss(b_fc1) + tf.nn.l2_loss(W_fc2) + tf.nn.l2_loss(b_fc2))

    cross_entropy = -tf.reduce_sum(y_ * tf.log(y_conv))
    train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
    correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

    sess = tf.Session()
    sess.run(tf.initialize_all_variables())

    for i in range(num_batches):
        batch = mnist.train.next_batch(50)
        if i % 100 == 0:
            train_accuracy = accuracy.eval(
                {x: batch[0], y_: batch[1]}, sess)
            print ("step %d/%d, training accuracy %g" % (i*batch_size,num_examples, train_accuracy))
        train_step.run(
            {x: batch[0], y_: batch[1]}, sess)

    print ("test accuracy %g" % accuracy.eval(
        {x: mnist.test.images, y_: mnist.test.labels}, sess))

sess.close()
# Out:
# step 0/55000, training accuracy 0.1
# step 5000/55000, training accuracy 0.76
# step 10000/55000, training accuracy 0.92
# step 15000/55000, training accuracy 0.86
# step 20000/55000, training accuracy 0.94
# step 25000/55000, training accuracy 0.9
# step 30000/55000, training accuracy 0.98
# step 35000/55000, training accuracy 0.94
# step 40000/55000, training accuracy 0.86
# step 45000/55000, training accuracy 1
# step 50000/55000, training accuracy 0.9
# test accuracy 0.9526

# %%
def shuffle_data(data_x, data_y):
  indices = np.arange(data_x.shape[0])
  np.random.shuffle(indices)
  shuffled_data_x = np.ascontiguousarray(data_x[indices])
  shuffled_data_y = np.ascontiguousarray(data_y[indices])
  return shuffled_data_x, shuffled_data_y

def unpickle(file):
  fo = open(file, 'rb')
  dict = pickle.load(fo, encoding='latin1')
  fo.close()
  return dict

DATA_DIR = '/path/to/data/'


train_x = np.ndarray((0, img_height * img_width * num_channels), dtype=np.float32)
train_y = []
for i in range(1, 6):
  subset = unpickle(os.path.join(DATA_DIR, 'data_batch_%d' % i))
  train_x = np.vstack((train_x, subset['data']))
  train_y += subset['labels']
train_x = train_x.reshape((-1, num_channels, img_height, img_width)).transpose(0,2,3,1)
train_y = np.array(train_y, dtype=np.int32)

subset = unpickle(os.path.join(DATA_DIR, 'test_batch'))
test_x = subset['data'].reshape((-1, num_channels, img_height, img_width)).transpose(0,2,3,1).astype(np.float32)
test_y = np.array(subset['labels'], dtype=np.int32)

valid_size = 5000
train_x, train_y = shuffle_data(train_x, train_y)
valid_x = train_x[:valid_size, ...]
valid_y = train_y[:valid_size, ...]
train_x = train_x[valid_size:, ...]
train_y = train_y[valid_size:, ...]
data_mean = train_x.mean((0,1,2))
data_std = train_x.std((0,1,2))

train_x = (train_x - data_mean) / data_std
valid_x = (valid_x - data_mean) / data_std
test_x = (test_x - data_mean) / data_std

# %%
sess = tf.Session()
sess.run(tf.initialize_all_variables())

conv1_var = tf.contrib.framework.get_variables('model/conv1_1/weights:0')[0]
conv1_weights = conv1_var.eval(session=sess)
draw_conv_filters(0, 0, conv1_weights, SAVE_DIR)

# %%
def draw_conv_filters(epoch, step, weights, save_dir):
  w = weights.copy()
  num_filters = w.shape[3]
  num_channels = w.shape[2]
  k = w.shape[0]
  assert w.shape[0] == w.shape[1]
  w = w.reshape(k, k, num_channels, num_filters)
  w -= w.min()
  w /= w.max()
  border = 1
  cols = 8
  rows = math.ceil(num_filters / cols)
  width = cols * k + (cols-1) * border
  height = rows * k + (rows-1) * border
  img = np.zeros([height, width, num_channels])
  for i in range(num_filters):
    r = int(i / cols) * (k + border)
    c = int(i % cols) * (k + border)
    img[r:r+k,c:c+k,:] = w[:,:,:,i]
  filename = 'epoch_%02d_step_%06d.png' % (epoch, step)
  ski.io.imsave(os.path.join(save_dir, filename), img)

# %%
import skimage as ski
import skimage.io

def draw_image(img, mean, std):
  img *= std
  img += mean
  img = img.astype(np.uint8)
  ski.io.imshow(img)
  ski.io.show()

# %%
def plot_training_progress(save_dir, data):
  fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,8))

  linewidth = 2
  legend_size = 10
  train_color = 'm'
  val_color = 'c'

  num_points = len(data['train_loss'])
  x_data = np.linspace(1, num_points, num_points)
  ax1.set_title('Cross-entropy loss')
  ax1.plot(x_data, data['train_loss'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
  ax1.plot(x_data, data['valid_loss'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
  ax1.legend(loc='upper right', fontsize=legend_size)
  ax2.set_title('Average class accuracy')
  ax2.plot(x_data, data['train_acc'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
  ax2.plot(x_data, data['valid_acc'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
  ax2.legend(loc='upper left', fontsize=legend_size)
  ax3.set_title('Learning rate')
  ax3.plot(x_data, data['lr'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='learning_rate')
  ax3.legend(loc='upper left', fontsize=legend_size)

  save_path = os.path.join(save_dir, 'training_plot.pdf')
  print('Plotting in: ', save_path)
  plt.savefig(save_path)

# %%
plot_data = {}
plot_data['train_loss'] = []
plot_data['valid_loss'] = []
plot_data['train_acc'] = []
plot_data['valid_acc'] = []
plot_data['lr'] = []
for epoch_num in range(1, num_epochs + 1):
  train_x, train_y = shuffle_data(train_x, train_y)
  for step in range(num_batches):
    offset = step * batch_size 
    # s ovim kodom pazite da je broj primjera djeljiv s batch_size
    batch_x = train_x[offset:(offset + batch_size), ...]
    batch_y = train_y[offset:(offset + batch_size)]
    feed_dict = {node_x: batch_x, node_y: batch_y}
    start_time = time.time()
    run_ops = [train_op, loss, logits]
    ret_val = sess.run(run_ops, feed_dict=feed_dict)
    _, loss_val, logits_val = ret_val
    duration = time.time() - start_time
    if (step+1) % 50 == 0:
      sec_per_batch = float(duration)
      format_str = 'epoch %d, step %d / %d, loss = %.2f (%.3f sec/batch)'
      print(format_str % (epoch_num, step+1, num_batches, loss_val, sec_per_batch))

  print('Train error:')
  train_loss, train_acc = evaluate(logits, loss, train_x, train_y)
  print('Validation error:')
  valid_loss, valid_acc = evaluate(logits, loss, valid_x, valid_y)
  plot_data['train_loss'] += [train_loss]
  plot_data['valid_loss'] += [valid_loss]
  plot_data['train_acc'] += [train_acc]
  plot_data['valid_acc'] += [valid_acc]
  plot_data['lr'] += [lr.eval(session=sess)]
  plot_training_progress(SAVE_DIR, plot_data)
